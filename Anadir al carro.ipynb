# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

# Configurar WebDriver
driver = webdriver.Chrome()

# Abrir la página
driver.get("https://tienda.mercadona.es/")

# Rechazar cookies
cookies = WebDriverWait(driver, 10).until(
    EC.presence_of_element_located((By.XPATH, "//button[text()='Rechazar']"))
)
cookies.click()

# Introducir código postal
cod_post = driver.find_element(By.CSS_SELECTOR, 'input[data-testid="postal-code-checker-input"]')
cod_post.send_keys('46940')

# Aceptar código postal
aceptar = driver.find_element(By.XPATH, "//span[text()='Continuar']")
aceptar.click()

idioma = driver.find_element(By.TAG_NAME, "input")

WebDriverWait(driver, 5).until(EC.presence_of_element_located( # espera que aparezca un boton en la pantalla
    (By.CSS_SELECTOR, "a[href='/categories']")))
search = driver.find_element(By.TAG_NAME, "input")

ingredients = ['sal', 'ternera', 'spaghetti']

for product in ingredients: 
    search.send_keys(product)
    WebDriverWait(driver, 5).until(EC.presence_of_element_located( # espera que aparezca un boton en la pantalla
    (By.CLASS_NAME,'button.button-rounded.button-rounded.button-rounded--small.button--small.product-quantity-button__add')))
    button = driver.find_element(By.CLASS_NAME,'button.button-rounded.button-rounded.button-rounded--small.button--small.product-quantity-button__add')
    button.click()
    WebDriverWait(driver, 5).until(EC.presence_of_element_located( # espera que aparezca un boton en la pantalla
    (By.CLASS_NAME,'ui-button.ui-button--default.ui-button--quaternary.ui-button--positive.ui-button--full-width')))
    no = driver.find_element(By.CLASS_NAME,'ui-button.ui-button--default.ui-button--quaternary.ui-button--positive.ui-button--full-width')
    no.click()
    search.clear()
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# Cell In[34], line 39
#      36 WebDriverWait(driver, 5).until(EC.presence_of_element_located( # espera que aparezca un boton en la pantalla
#      37 (By.CLASS_NAME,'button.button-rounded.button-rounded.button-rounded--small.button--small.product-quantity-button__add')))
#      38 button = driver.find_element(By.CLASS_NAME,'button.button-rounded.button-rounded.button-rounded--small.button--small.product-quantity-button__add')
# ---> 39 button.click()
#      40 if product == ingredients[1]:
#      41     WebDriverWait(driver, 5).until(EC.presence_of_element_located( # espera que aparezca un boton en la pantalla
#      42     (By.CLASS_NAME,'ui-button.ui-button--default.ui-button--quaternary.ui-button--positive.ui-button--full-width')))
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:94, in WebElement.click(self)
#      92 def click(self) -> None:
#      93     """Clicks the element."""
# ---> 94     self._execute(Command.CLICK_ELEMENT)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:380, in WebDriver.execute(self, driver_command, params)
#     378 response = self.command_executor.execute(driver_command, params)
#     379 if response:
# --> 380     self.error_handler.check_response(response)
#     381     response["value"] = self._unwrap_value(response.get("value", None))
#     382     return response
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# ElementClickInterceptedException: Message: element click intercepted: Element <button type="button" aria-label="Añadir al carro" class="button button-rounded button-rounded--small button--small product-quantity-button__add" data-testid="product-quantity-button">...</button> is not clickable at point (444, 490). Other element would receive the click: <div class="ui-modal ui-medium-modal">...</div>
#   (Session info: chrome=135.0.7049.85)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF797B15335+78597]
# 	GetHandleVerifier [0x00007FF797B15390+78688]
# 	(No symbol) [0x00007FF7978C91AA]
# 	(No symbol) [0x00007FF797927089]
# 	(No symbol) [0x00007FF797924A42]
# 	(No symbol) [0x00007FF797921AE1]
# 	(No symbol) [0x00007FF797920A42]
# 	(No symbol) [0x00007FF797912204]
# 	(No symbol) [0x00007FF7979470EA]
# 	(No symbol) [0x00007FF797911AB6]
# 	(No symbol) [0x00007FF797947300]
# 	(No symbol) [0x00007FF79796F2BB]
# 	(No symbol) [0x00007FF797946EC3]
# 	(No symbol) [0x00007FF7979103F8]
# 	(No symbol) [0x00007FF797911163]
# 	GetHandleVerifier [0x00007FF797DBEEED+2870973]
# 	GetHandleVerifier [0x00007FF797DB9698+2848360]
# 	GetHandleVerifier [0x00007FF797DD6973+2967875]
# 	GetHandleVerifier [0x00007FF797B3017A+188746]
# 	GetHandleVerifier [0x00007FF797B3845F+222255]
# 	GetHandleVerifier [0x00007FF797B1D2B4+111236]
# 	GetHandleVerifier [0x00007FF797B1D462+111666]
# 	GetHandleVerifier [0x00007FF797B03589+5465]
# 	BaseThreadInitThunk [0x00007FFCE0797374+20]
# 	RtlUserThreadStart [0x00007FFCE0F7CC91+33]
